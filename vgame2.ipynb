# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('vgames2.csv')
df = df.sort_values('Name',ascending=True)
no = np.arange(0,16598,1)
df['No'] = no
df.set_index('No', inplace = True)
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df[df['Year'].isnull()]
# Out:
#                                              Name Platform  Year  \
# No
# 147        AKB1/48: Idol to Guam de Koishitara...     X360   NaN
# 198                  Action Man-Operation Extreme       PS   NaN
# 214                    Advance Wars: Days of Ruin       DS   NaN
# 217                                     Adventure     2600   NaN
# 250                  Agarest Senki: Re-appearance      PS3   NaN
# ...                                           ...      ...   ...
# 16405              Yu Yu Hakusho: Dark Tournament      PS2   NaN
# 16412  Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)      Wii   NaN
# 16498                    Zero: Tsukihami no Kamen      Wii   NaN
# 16568                              eJay Clubworld      PS2   NaN
# 16596                  wwe Smackdown vs. Raw 2006      PS2   NaN
#
#               Genre           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# No
# 147            Misc                 NaN        0        0     0.01           0
# ...

# %%
df['Platform'].unique()
# Out:
# array(['PS', 'PS2', 'PSP', 'PS3', 'X360', 'PC', 'DS', 'Wii', 'N64', '3DS',
#        'GC', 'XB', 'NES', 'GBA', 'PSV', 'PS4', 'XOne', 'SNES', '2600',
#        'WiiU', 'SAT', 'GB', 'NG', 'GEN', 'PCFX', 'DC', '3DO', 'WS',
#        'TG16', 'SCD', 'GG'], dtype=object)

# %%
df[df['Platform'] == 'WS']
# Out:
#                                             Name Platform    Year  \
# No
# 2105   Chocobo no Fushigi Dungeon for WonderSwan       WS  1999.0
# 3068              Digimon Adventure: Anode Tamer       WS  1999.0
# 4512                               Final Fantasy       WS  2000.0
# 4527                            Final Fantasy II       WS  2001.0
# 11703      SD Gundam G Generation: Gather Beat 2       WS  2001.0
# 13424      Super Robot Taisen Compact 2 Dai-1-Bu       WS  2000.0
#
#               Genre           Publisher NA_Sales EU_Sales JP_Sales Other_Sales
# No
# 2105   Role-Playing  Namco Bandai Games        0        0     0.18           0
# 3068   Role-Playing  Namco Bandai Games        0        0     0.28           0
# 4512   Role-Playing          SquareSoft        0        0     0.51           0
# 4527   Role-Playing          SquareSoft        0        0     0.25           0
# 11703      Strategy  Namco Bandai Games        0        0     0.03           0
# ...
